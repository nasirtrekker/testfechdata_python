# %%
import math
import pandas as pd
import pylab as pl
import numpy as np
import json
import datetime
import matplotlib

# %%
data = pd.read_json('30NovVerbond1.json', orient='columns')
data
# Out:
#                                                     data   more
# 0      {'value': 0, 'timestamp': '2017-10-20T14:32:34...  False
# 1      {'value': 3.33333, 'timestamp': '2017-11-01T15...  False
# 2      {'value': 3.283339999999999, 'timestamp': '201...  False
# 3      {'value': 3.266660000000001, 'timestamp': '201...  False
# 4      {'value': 3.333339999999999, 'timestamp': '201...  False
# 5      {'value': 3.283329999999999, 'timestamp': '201...  False
# 6      {'value': 3.133340000000004, 'timestamp': '201...  False
# 7      {'value': 2.633330000000001, 'timestamp': '201...  False
# 8      {'value': 2.5, 'timestamp': '2017-11-01T15:33:...  False
# 9      {'value': 2.483329999999995, 'timestamp': '201...  False
# 10     {'value': 2.416670000000003, 'timestamp': '201...  False
# 11     {'value': 2.416669999999996, 'timestamp': '201...  False
# 12     {'value': 2.433329999999998, 'timestamp': '201...  False
# 13     {'value': 2.483330000000009, 'timestamp': '201...  False
# ...

# %%
# read as index
value_timestamp = pd.read_json(data['data'].to_json(), orient='index')
value_timestamp
# Out:
#                     timestamp    value
# 0     2017-10-20 14:32:34.441  0.00000
# 1     2017-11-01 15:21:20.692  3.33333
# 10    2017-11-01 15:40:21.126  2.41667
# 100   2017-11-01 18:43:25.078  2.50000
# 1000  2017-11-02 23:41:03.322  2.51667
# 10000 2017-11-14 13:53:11.878  3.06666
# 10001 2017-11-14 13:54:11.899  3.80000
# 10002 2017-11-14 14:00:12.028  3.06667
# 10003 2017-11-14 14:01:12.067  3.13333
# 10004 2017-11-14 14:02:12.088  3.08333
# 10005 2017-11-14 14:03:12.106  3.08334
# 10006 2017-11-14 14:04:12.127  3.10000
# 10007 2017-11-14 14:10:12.264  3.06667
# 10008 2017-11-14 14:11:12.287  3.08333
# 10009 2017-11-14 14:12:12.310  3.05000
# 1001  2017-11-02 23:42:03.344  2.51667
# 10010 2017-11-14 14:13:12.333  3.10000
# 10011 2017-11-14 14:14:12.356  3.05000
# 10012 2017-11-14 14:20:12.488  3.45000
# 10013 2017-11-14 14:21:12.512  3.06666
# 10014 2017-11-14 14:22:12.534  3.05000
# 10015 2017-11-14 14:23:12.552  3.03334
# 10016 2017-11-14 14:24:12.573  3.11666
# ...

# %%
## plot
# %matplotlib inline
import matplotlib.pyplot as plt
value_timestamp.plot(x='timestamp',y='value')
plt.show()
